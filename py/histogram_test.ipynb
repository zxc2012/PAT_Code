# %%
import numpy as np

# %%
X=np.arange(12).reshape(3,4)
mask=np.array([1,0,1,0],dtype=bool)
row=np.array([0,1,2])
X[row[:,np.newaxis],mask]
# Out:
# array([[ 0,  2],
#        [ 4,  6],
#        [ 8, 10]])

# %%
mask=np.array([1,0,1,0])
X[row[:,np.newaxis],mask]
# Out:
# array([[1, 0, 1, 0],
#        [5, 4, 5, 4],
#        [9, 8, 9, 8]])

# %%
help np.searchsorted()
# Out:
#   File "<ipython-input-6-d61a3700c3b9>", line 1
#     help np.searchsorted()
#           ^
# SyntaxError: invalid syntax

# %%
help(np.searchsorted())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c3a93515016b> in <module>
# ----> 1 help(np.searchsorted())
#
# <__array_function__ internals> in searchsorted(*args, **kwargs)
#
# TypeError: _searchsorted_dispatcher() missing 2 required positional arguments: 'a' and 'v'

# %%
help(np.searchsorted)
# Out:
# Help on function searchsorted in module numpy:
#
# searchsorted(a, v, side='left', sorter=None)
#     Find indices where elements should be inserted to maintain order.
#
#     Find the indices into a sorted array `a` such that, if the
#     corresponding elements in `v` were inserted before the indices, the
#     order of `a` would be preserved.
#
#     Assuming that `a` is sorted:
#
#     ======  ============================
#     `side`  returned index `i` satisfies
#     ======  ============================
#     left    ``a[i-1] < v <= a[i]``
#     right   ``a[i-1] <= v < a[i]``
#     ======  ============================
#
#     Parameters
#     ----------
#     a : 1-D array_like
#         Input array. If `sorter` is None, then it must be sorted in
#         ascending order, otherwise `sorter` must be an array of indices
#         that sort it.
#     v : array_like
#         Values to insert into `a`.
#     side : {'left', 'right'}, optional
# ...

# %%
import matplotlib.pyplot as plt
np.random.seed(42)
x=np.random.randn(10000)
bins=np.linspace(-5,5,20)
counts=np.zeros_like(bins)
i=np.searchsorted(bins,x)
np.add.at(counts,i,1)
plt.plot(bins,counts,linestyle='steps')
# Out:
# D:\MDK\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).

# %%
help(np.random.randn)
# Out:
# Help on built-in function randn:
#
# randn(...) method of numpy.random.mtrand.RandomState instance
#     randn(d0, d1, ..., dn)
#
#     Return a sample (or samples) from the "standard normal" distribution.
#
#     .. note::
#         This is a convenience function for users porting code from Matlab,
#         and wraps `numpy.random.standard_normal`. That function takes a
#         tuple to specify the size of the output, which is consistent with
#         other NumPy functions like `numpy.zeros` and `numpy.ones`.
#
#     If positive int_like arguments are provided, `randn` generates an array
#     of shape ``(d0, d1, ..., dn)``, filled
#     with random floats sampled from a univariate "normal" (Gaussian)
#     distribution of mean 0 and variance 1. A single float randomly sampled
#     from the distribution is returned if no argument is provided.
#
#     Parameters
#     ----------
#     d0, d1, ..., dn : int, optional
# ...

# %%
plt.plot(bins,counts,drawstyle='steps')

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=None, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, normed=None, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*,...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported at present.
#
#     Parameters
#     ----------
# ...

# %%
x=rand.rand(20,2)
y=sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
nearest=np.argpartition(y,5,axis=1)
for i in range(x.shape(0)):
    for j in nearest[i,:6]:
        plt(*zip(x[i],x[j]),color='b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31ce9a6fe5e9> in <module>
# ----> 1 x=rand.rand(20,2)
#       2 y=sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
#       3 nearest=np.argpartition(y,5,axis=1)
#       4 for i in range(x.shape(0)):
#       5     for j in nearest[i,:6]:
#
# NameError: name 'rand' is not defined

# %%
rand=np.random.RandomState(42)
x=rand.rand(20,2)
y=sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
nearest=np.argpartition(y,5,axis=1)
for i in range(x.shape(0)):
    for j in nearest[i,:6]:
        plt(*zip(x[i],x[j]),color='b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-18a939cb512b> in <module>
# ----> 1 rand=np.random.RandomState(42)
#       2 x=rand.rand(20,2)
#       3 y=sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
#       4 nearest=np.argpartition(y,5,axis=1)
#       5 for i in range(x.shape(0)):
#
# NameError: name 'np' is not defined

# %%
import numpy as np
rand=np.random.RandomState(42)
x=rand.rand(20,2)
y=sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
nearest=np.argpartition(y,5,axis=1)
for i in range(x.shape(0)):
    for j in nearest[i,:6]:
        plt(*zip(x[i],x[j]),color='b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-59a2ad9dcef8> in <module>
#       2 rand=np.random.RandomState(42)
#       3 x=rand.rand(20,2)
# ----> 4 y=sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
#       5 nearest=np.argpartition(y,5,axis=1)
#       6 for i in range(x.shape(0)):
#
# TypeError: sum() takes no keyword arguments

# %%
rand=np.random.RandomState(42)
x=rand.rand(20,2)
y=np.sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
nearest=np.argpartition(y,5,axis=1)
for i in range(x.shape(0)):
    for j in nearest[i,:6]:
        plt(*zip(x[i],x[j]),color='b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d6b643d8c260> in <module>
#       3 y=np.sum((x[np.newaxis,:,:]-x[:,np.newaxis,:])**2,axis=2)
#       4 nearest=np.argpartition(y,5,axis=1)
# ----> 5 for i in range(x.shape(0)):
#       6     for j in nearest[i,:6]:
#       7         plt(*zip(x[i],x[j]),color='b')
#
# TypeError: 'tuple' object is not callable

# %%
for i in range(x.shape[0]):
    for j in nearest[i,:6]:
        plt(*zip(x[i],x[j]),color='b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6760f7f11cb4> in <module>
#       1 for i in range(x.shape[0]):
#       2     for j in nearest[i,:6]:
# ----> 3         plt(*zip(x[i],x[j]),color='b')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
for i in range(x.shape[0]):
    for j in nearest[i,:6]:
        plt(*zip(x[i],x[j]),color='b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-eb9c4c9f7020> in <module>
#       2 for i in range(x.shape[0]):
#       3     for j in nearest[i,:6]:
# ----> 4         plt(*zip(x[i],x[j]),color='b')
#
# TypeError: 'module' object is not callable

# %%
for i in range(x.shape[0]):
    for j in nearest[i,:6]:
        plt.plot(*zip(x[i],x[j]),color='b')

# %%
for i in range(x.shape[0]):
    for j in nearest[i,:2]:
        plt.plot(*zip(x[i],x[j]),color='b')

# %%
for i in range(x.shape[0]):
    for j in nearest[i,0]:
        plt.plot(*zip(x[i],x[j]),color='b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2b0c003626e7> in <module>
#       1 for i in range(x.shape[0]):
# ----> 2     for j in nearest[i,0]:
#       3         plt.plot(*zip(x[i],x[j]),color='b')
#
# TypeError: 'numpy.int64' object is not iterable

# %%
for i in range(x.shape[0]):
    plt.plot(*zip(x[i],x[nearest[i,0]]),color='b')

# %%
for i in range(x.shape[0]):
    plt.scatter(x[:,0],x[:,1],edgecolors='g')
    plt.plot(*zip(x[i],x[nearest[i,0]]),color='b')
